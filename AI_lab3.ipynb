# %% [markdown]
# <a href="https://colab.research.google.com/github/202130582/AI-2024/blob/main/AI_lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
 'Name':['Alce', 'Bob',' Charlie', 'David'],
 ' Age':[25,30,17,28],
 ' Cty':['New york','San Francisco','Los Anglos',' Alexandria'],
'Salary':[100,150,200,300]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#        Name   Age            Cty  Salary
# 0      Alce    25       New york     100
# 1       Bob    30  San Francisco     150
# 2   Charlie    17     Los Anglos     200
# 3     David    28     Alexandria     300

# %%
print("The minimum salary is", df['Salary'].min())
print("The maximum salary is", df['Salary'].max())
print("The mean salary is", df['Salary'].mean())
# Out:
# The minimum salary is 100
# The maximum salary is 300
# The mean salary is 187.5

# %%
df.head(2)
# Out:
#    Name   Age            Cty  Salary
# 0  Alce    25       New york     100
# 1   Bob    30  San Francisco     150

# %%
df.tail(2)
# Out:
#        Name   Age          Cty  Salary
# 2   Charlie    17   Los Anglos     200
# 3     David    28   Alexandria     300

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1    Age    4 non-null      int64
#  2    Cty    4 non-null      object
#  3   Salary  4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
df.describe().T
# Out:
#         count   mean        std    min    25%    50%    75%    max
#  Age      4.0   25.0   5.715476   17.0   23.0   26.5   28.5   30.0
# Salary    4.0  187.5  85.391256  100.0  137.5  175.0  225.0  300.0

# %%
df
# Out:
#        Name   Age            Cty  Salary
# 0      Alce    25       New york     100
# 1       Bob    30  San Francisco     150
# 2   Charlie    17     Los Anglos     200
# 3     David    28     Alexandria     300

# %%
merged_df=pd.merge(df,df,on='Name')
merged_df
# Out:
#        Name   Age_x          Cty_x  Salary_x   Age_y          Cty_y  Salary_y
# 0      Alce      25       New york       100      25       New york       100
# 1       Bob      30  San Francisco       150      30  San Francisco       150
# 2   Charlie      17     Los Anglos       200      17     Los Anglos       200
# 3     David      28     Alexandria       300      28     Alexandria       300

# %%
df['New_Salary']=df['Salary'].apply(lambda x:x*1.2)
df
# Out:
#        Name   Age            Cty  Salary  New_Salary
# 0      Alce    25       New york     100       120.0
# 1       Bob    30  San Francisco     150       180.0
# 2   Charlie    17     Los Anglos     200       240.0
# 3     David    28     Alexandria     300       360.0

# %%
sorted_df = df.sort_values(by='Salary')
sorted_df
# Out:
#        Name   Age            Cty  Salary  New_Salary
# 0      Alce    25       New york     100       120.0
# 1       Bob    30  San Francisco     150       180.0
# 2   Charlie    17     Los Anglos     200       240.0
# 3     David    28     Alexandria     300       360.0

# %%
df1 = pd.read_csv('diabetes.csv')
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df1['Outcome'].unique()
# Out:
# array([1, 0])

# %%
correlation_
correlation

# %%
df1 = df1.rename(c)
