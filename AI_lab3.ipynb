# %% [markdown]
# <a href="https://colab.research.google.com/github/202130582/AI-2024/blob/main/AI_lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import datasets, model_selection
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# step1:load the data

# %%
df=pd.read_csv('BostonHousing.csv')
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df = df.rename(columns={'medv':'TARGET', 'rm':'RM', 'lstat':'LSTAT'})

# %%
 df[["LSTAT","RM","TARGET"]]
# Out:
#      LSTAT     RM  TARGET
# 0     4.98  6.575    24.0
# 1     9.14  6.421    21.6
# 2     4.03  7.185    34.7
# 3     2.94  6.998    33.4
# 4     5.33  7.147    36.2
# ..     ...    ...     ...
# 501   9.67  6.593    22.4
# 502   9.08  6.120    20.6
# 503   5.64  6.976    23.9
# 504   6.48  6.794    22.0
# 505   7.88  6.030    11.9
#
# [506 rows x 3 columns]

# %%
features = df[["LSTAT","RM"]]
target = df["TARGET"]
x1 = df["LSTAT"]
x2 = df["RM"]
y = target

# %%
plt.figure(figsize=(5, 4))

plt.subplot(1,2,1)

plt.scatter(x1, y)
plt.title("LSTAT")
plt.xlabel("LSTAT")
plt.ylabel("TARGET")
plt.grid(True)

plt.subplot(1,2,2)

plt.scatter(x2, y)
plt.title("RM")
plt.xlabel("RM")
plt.ylabel("TARGET")
plt.grid(True)
